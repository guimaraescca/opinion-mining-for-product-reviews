# %%
import pandas as pd
import rdflib
import rdflib.plugins.sparql as sparql
from rdflib.namespace import RDF, RDFS, OWL

import sys
sys.path[0] = '../src'

import utils
import ontology

# %%
onto_dict = ontology.ontology_to_dict('../data/external/ontologies/smartphone_aspects.owl')

# %%
# Display constructed Dictionary as a Pandas Dataframe
df = pd.DataFrame(list(onto_dict.items()), columns=['aspect', 'cluster'])

with pd.option_context('display.max_rows', None, 'display.max_columns', 3):
    display(df)
# Out:
#                                                 aspect              cluster
# 0                                            acessório            acessório
# 1                                               agenda               agenda
# 2                                               antena               antena
# 3                                           aplicativo           aplicativo
# 4                                              bateria              bateria
# 5                                        bloco de nota        bloco de nota
# 6                                            bluetooth            bluetooth
# 7                                                botão                botão
# 8                                                 cabo                 cabo
# 9                                           calendário           calendário
# 10                                          carregador           carregador
# ...
